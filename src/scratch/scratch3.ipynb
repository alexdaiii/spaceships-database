# %%
import datetime

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import networkx as nx

# %%
rng = np.random.default_rng(seed=42)

g = nx.balanced_tree(9, 1, nx.DiGraph)
nx.draw_kamada_kawai(g, with_labels=True)

# %%
for node in g.nodes:
    # print the node's parents
    val = list(g.predecessors(node))
    print(val)
# Out:
# []
# [0]
# [0]
# [0]
# [0]
# [0]
# [0]
# [0]
# [0]
# [0]

# %%
val[0]
# Out:
# 0

# %%
for i, j in zip(range(5), range(9)):
    print(i, j)
# Out:
# 0 0
# 1 1
# 2 2
# 3 3
# 4 4

# %%
dg = nx.dorogovtsev_goltsev_mendes_graph(2)
nx.draw_kamada_kawai(dg, with_labels=True)

# %%
for n in dg:
    print(list(dg.neighbors(n)))
# Out:
# [1, 2, 3, 4]
# [0, 2, 3, 5]
# [0, 1, 4, 5]
# [0, 1]
# [0, 2]
# [1, 2]

# %%
g = nx.tadpole_graph(8, 2)
nx.draw(g, with_labels=True)
